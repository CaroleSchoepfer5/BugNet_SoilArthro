# %%
from ultralytics import YOLO

data_dir = r"N:\alpenv\GOES\Projects\Bugnet\BugNet Davos\Students\Carole\Machine Learnig Models\classifier"  # folder that contains train/ and val/

# %%
# Try YOLOv8 tiny classifier (good starting point)
model = YOLO("yolov8n-cls.pt")  # n = nano (smallest)

model.train(
    data=data_dir,
    epochs=30,       # start small, you can increase later
    imgsz=224,       # default for classification
    batch=30,        # reduce if you run out of RAM
    patience=5,      # early stopping
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.18 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.236  Python-3.11.14 torch-2.9.1+cpu CPU (Intel Core(TM) i7-1065G7 1.30GHz)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=30, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=N:\alpenv\GOES\Projects\Bugnet\BugNet Davos\Students\Carole\Machine Learnig Models\classifier, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=30, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=224, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n-cls.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train5, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=5, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\carol\runs\classify\train5, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=classify, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
#
# WARNING Dataset not found, missing path \\wsl.ch\fe\alpenv\GOES\Projects\Bugnet\BugNet Davos\Students\Carole\Machine Learnig Models\classifier, attempting download...
# WARNING Download failure, retrying 1/3 https://ultralytics.com/assets/N://alpenv/GOES/Projects/Bugnet/BugNet Davos/Students/Carole/Machine Learnig Models/classifier.zip... URL can't contain control characters. '/ultralytics/assets/releases/download/v0.0.0/N:\\alpenv\\GOES\\Projects\\Bugnet\\BugNet Davos\\Students\\Carole\\Machine Learnig Models\\classifier.zip' (found at least ' ')
# WARNING Download failure, retrying 2/3 https://ultralytics.com/assets/N://alpenv/GOES/Projects/Bugnet/BugNet Davos/Students/Carole/Machine Learnig Models/classifier.zip... Curl return value 3
# WARNING Download failure, retrying 3/3 https://ultralytics.com/assets/N://alpenv/GOES/Projects/Bugnet/BugNet Davos/Students/Carole/Machine Learnig Models/classifier.zip... Curl return value 3
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# File ~\anaconda3\envs\bugcls\Lib\site-packages\ultralytics\utils\downloads.py:329, in safe_download(url, file, dir, unzip, delete, curl, retry, min_bytes, exist_ok, progress)
#     328 r = subprocess.run(["curl", "-#", f"-{s}L", url, "-o", f, "--retry", "3", "-C", "-"]).returncode
# --> 329 assert r == 0, f"Curl return value {r}"
#     330 expected_size = None  # Can't get size with curl
#
# AssertionError: Curl return value 3
#
# The above exception was the direct cause of the following exception:
#
# ConnectionError                           Traceback (most recent call last)
# File ~\anaconda3\envs\bugcls\Lib\site-packages\ultralytics\engine\trainer.py:633, in BaseTrainer.get_dataset(self)
#     632 if self.args.task == "classify":
# --> 633     data = check_cls_dataset(self.args.data)
#     634 elif str(self.args.data).rsplit(".", 1)[-1] == "ndjson":
#     635     # Convert NDJSON to YOLO format
#
# File ~\anaconda3\envs\bugcls\Lib\site-packages\ultralytics\data\utils.py:520, in check_cls_dataset(dataset, split)
#     519 else:
# --> 520     download(f"{ASSETS_URL}/{dataset}.zip", dir=data_dir.parent)
#     521 LOGGER.info(f"Dataset download success ✅ ({time.time() - t:.1f}s), saved to {colorstr('bold', data_dir)}\n")
#
# File ~\anaconda3\envs\bugcls\Lib\site-packages\ultralytics\utils\downloads.py:529, in download(url, dir, unzip, delete, curl, threads, retry, exist_ok)
#     528 for u in urls:
# --> 529     safe_download(url=u, dir=dir, unzip=unzip, delete=delete, curl=curl, retry=retry, exist_ok=exist_ok)
#
# File ~\anaconda3\envs\bugcls\Lib\site-packages\ultralytics\utils\downloads.py:370, in safe_download(url, file, dir, unzip, delete, curl, retry, min_bytes, exist_ok, progress)
#     369 elif i >= retry:
# --> 370     raise ConnectionError(emojis(f"❌  Download failure for {uri}. Retry limit reached. {e}")) from e
#     371 LOGGER.warning(f"Download failure, retrying {i + 1}/{retry} {uri}... {e}")
#
# ConnectionError:   Download failure for https://ultralytics.com/assets/N://alpenv/GOES/Projects/Bugnet/BugNet Davos/Students/Carole/Machine Learnig Models/classifier.zip. Retry limit reached. Curl return value 3
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 4
#       1 # Try YOLOv8 tiny classifier (good starting point)
#       2 model = YOLO("yolov8n-cls.pt")  # n = nano (smallest)
# ----> 4 model.train(
#       5     data=data_dir,
#       6     epochs=30,       # start small, you can increase later
#       7     imgsz=224,       # default for classification
#       8     batch=30,        # reduce if you run out of RAM
#       9     patience=5,      # early stopping
#      10 )
#
# File ~\anaconda3\envs\bugcls\Lib\site-packages\ultralytics\engine\model.py:768, in Model.train(self, trainer, **kwargs)
#     765 if args.get("resume"):
#     766     args["resume"] = self.ckpt_path
# --> 768 self.trainer = (trainer or self._smart_load("trainer"))(overrides=args, _callbacks=self.callbacks)
#     769 if not args.get("resume"):  # manually set model only if not resuming
#     770     self.trainer.model = self.trainer.get_model(weights=self.model if self.ckpt else None, cfg=self.model.yaml)
#
# File ~\anaconda3\envs\bugcls\Lib\site-packages\ultralytics\models\yolo\classify\train.py:65, in ClassificationTrainer.__init__(self, cfg, overrides, _callbacks)
#      63 if overrides.get("imgsz") is None:
#      64     overrides["imgsz"] = 224
# ---> 65 super().__init__(cfg, overrides, _callbacks)
#
# File ~\anaconda3\envs\bugcls\Lib\site-packages\ultralytics\engine\trainer.py:163, in BaseTrainer.__init__(self, cfg, overrides, _callbacks)
#     161 self.model = check_model_file_from_stem(self.args.model)  # add suffix, i.e. yolo11n -> yolo11n.pt
#     162 with torch_distributed_zero_first(LOCAL_RANK):  # avoid auto-downloading dataset multiple times
# --> 163     self.data = self.get_dataset()
#     165 self.ema = None
#     167 # Optimization utils init
#
# File ~\anaconda3\envs\bugcls\Lib\site-packages\ultralytics\engine\trainer.py:653, in BaseTrainer.get_dataset(self)
#     651             self.args.data = data["yaml_file"]  # for validating 'yolo train data=url.zip' usage
#     652 except Exception as e:
# --> 653     raise RuntimeError(emojis(f"Dataset '{clean_url(self.args.data)}' error ❌ {e}")) from e
#     654 if self.args.single_cls:
#     655     LOGGER.info("Overriding class names with single class.")
#
# RuntimeError: Dataset 'N://alpenv/GOES/Projects/Bugnet/BugNet Davos/Students/Carole/Machine Learnig Models/classifier' error    Download failure for https://ultralytics.com/assets/N://alpenv/GOES/Projects/Bugnet/BugNet Davos/Students/Carole/Machine Learnig Models/classifier.zip. Retry limit reached. Curl return value 3

# %%
from ultralytics import YOLO
import os
import shutil

# path to the trained classifier
cls_model_path = r"N:\alpenv\GOES\Projects\Bugnet\BugNet Davos\Students\Carole\Machine Learning Models\classifier\best.pt"
model = YOLO(cls_model_path)

source_dir = r"N:\alpenv\GOES\Projects\Bugnet\BugNet Davos\Students\Carole\Machine Learning Models\crops_to_sort\output"
dest_root  = r"N:\alpenv\GOES\Projects\Bugnet\BugNet Davos\Students\Carole\Machine Learning Models\crops_sorted"

os.makedirs(dest_root, exist_ok=True)

# class names from your trained model (e.g. {'0': 'class1', ...} or {0: 'class1', ...})
class_names = model.names

# make subfolders for each class
for cname in class_names.values():
    os.makedirs(os.path.join(dest_root, cname), exist_ok=True)

for fname in os.listdir(source_dir):
    if not fname.lower().endswith((".jpg", ".jpeg", ".png")):
        continue

    fpath = os.path.join(source_dir, fname)
    results = model.predict(fpath, verbose=False)

    probs = results[0].probs
    top_idx = int(probs.top1)
    top_conf = float(probs.top1conf)
    top_name = class_names[top_idx]

    # Only auto-move if confident enough
    if top_conf < 0.85:
        print(f"Low conf {top_conf:.2f} for {fname} -> {top_name}, skipping.")
        continue

    dst = os.path.join(dest_root, top_name, fname)
    shutil.move(fpath, dst)
# Out:
# Low conf 0.79 for Bruech23A_3 (8)_6.png -> prositg, skipping.
# Low conf 0.82 for Bruech23A_3 (8)_3.png -> prositg, skipping.
# Low conf 0.63 for Bruech23A_3 (8)_2.png -> entomo_y, skipping.
# Low conf 0.81 for Bruech23A_3 (2)_1.png -> orib, skipping.
# Low conf 0.81 for Bruech23A_3 (24)_3.png -> sym, skipping.
# Low conf 0.73 for Bruech23A_3 (14)_1.png -> prositg, skipping.
# Low conf 0.73 for Bruech23A_3 (18)_5.png -> sym, skipping.
# Low conf 0.81 for Bruech23A_3 (18)_3.png -> entomo_y, skipping.
# Low conf 0.73 for Bruech23A_3 (14)_3.png -> orib, skipping.
# Low conf 0.64 for Bruech23A_3 (16)_1.png -> orib, skipping.
# Low conf 0.67 for Bruech18A_3 (7)_6.png -> prositg, skipping.
# Low conf 0.40 for Bruech18A_3 (5)_5.png -> prositg, skipping.
# Low conf 0.76 for Bruech18A_3 (23)_3.png -> prositg, skipping.
# Low conf 0.72 for Bruech18A_3 (18)_5.png -> sym, skipping.
# Low conf 0.62 for Bruech18A_3 (13)_1.png -> prositg, skipping.
# Low conf 0.63 for Bruech18A_3 (1)_2.png -> orib, skipping.
# Low conf 0.57 for Bruech17A_3 (9)_4.png -> sym, skipping.
# Low conf 0.58 for Bruech17A_3 (31)_3.png -> meso_h, skipping.
# Low conf 0.73 for Bruech17A_3 (3)_10.png -> prositg, skipping.
# Low conf 0.67 for Bruech17A_3 (28)_4.png -> prositg, skipping.
# Low conf 0.66 for Bruech17A_3 (24)_5.png -> entomo_y, skipping.
# Low conf 0.58 for Bruech17A_3 (2)_5.png -> entomo_y, skipping.
# Low conf 0.56 for Bruech17A_3 (22)_4.png -> entomo_y, skipping.
# Low conf 0.68 for Bruech17A_3 (19)_7.png -> entomo_y, skipping.
# Low conf 0.84 for Bruech17A_3 (19)_2.png -> sym, skipping.
# Low conf 0.37 for Bruech17A_3 (17)_3.png -> prositg, skipping.
# Low conf 0.32 for Bruech17A_3 (17)_5.png -> prositg, skipping.
# Low conf 0.64 for Bruech17A_3 (15)_7.png -> orib, skipping.
# Low conf 0.66 for Bruech17A_3 (16)_2.png -> prositg, skipping.
# Low conf 0.53 for Bruech17A_3 (13)_7.png -> entomo_y, skipping.
# Low conf 0.75 for Bruech17A_3 (11)_10.png -> entomo_y, skipping.
# Low conf 0.71 for Bruech17A_3 (10)_6.png -> entomo_y, skipping.
# Low conf 0.42 for Bruech14A_3 (3)_11.png -> prositg, skipping.
# Low conf 0.58 for Bruech14A_3 (2)_13.png -> orib, skipping.
# Low conf 0.74 for Bruech14A_3 (2)_3.png -> entomo_y, skipping.
# Low conf 0.83 for Bruech14A_3 (2)_6.png -> entomo_y, skipping.
# Low conf 0.52 for Bruech14A_3 (1)_3.png -> entomo_y, skipping.
# Low conf 0.67 for Bruech14A_3 (3)_1.png -> sym, skipping.
# Low conf 0.76 for Bruech14A_3 (2)_5.png -> prositg, skipping.
# Low conf 0.76 for Bruech14A_3 (1)_18.png -> prositg, skipping.
# Low conf 0.52 for Bruech14A_3 (1)_2.png -> entomo_y, skipping.
# Low conf 0.79 for Bruech06A_3 (32)_10.png -> entomo_y, skipping.
# Low conf 0.82 for Bruech11A_3 (7)_6.png -> orib, skipping.
# Low conf 0.58 for Bruech09A_3 (8)_3.png -> orib, skipping.
# Low conf 0.77 for Bruech11A_3 (18)_3.png -> entomo_y, skipping.
# Low conf 0.83 for Bruech06A_3 (30)_6.png -> prositg, skipping.
# Low conf 0.55 for Bruech06A_3 (28)_13.png -> orib, skipping.
# Low conf 0.68 for Bruech06A_3 (4)_10.png -> sym, skipping.
# Low conf 0.63 for Bruech06A_3 (24)_13.png -> sym, skipping.
# Low conf 0.82 for Bruech09A_3 (1)_13.png -> entomo_y, skipping.
# Low conf 0.64 for Bruech06A_3 (9)_10.png -> sym, skipping.
# Low conf 0.59 for Bruech11A_3 (17)_8.png -> meso_h, skipping.
# Low conf 0.39 for Bruech06A_3 (9)_9.png -> sym, skipping.
# Low conf 0.80 for Bruech06A_3 (4)_5.png -> entomo_y, skipping.
# Low conf 0.78 for Bruech06A_3 (30)_1.png -> entomo_y, skipping.
# Low conf 0.52 for Bruech06A_3 (31)_10.png -> prositg, skipping.
# Low conf 0.46 for Bruech09A_3 (4)_8.png -> entomo_y, skipping.
# Low conf 0.65 for Bruech06A_3 (10)_5.png -> sym, skipping.
# Low conf 0.80 for Bruech06A_3 (10)_8.png -> prositg, skipping.
# Low conf 0.61 for Bruech06A_3 (10)_2.png -> entomo_y, skipping.
# Low conf 0.73 for Bruech02A_3 (1)_9.png -> prositg, skipping.
# Low conf 0.73 for Bruech02A_3 (1)_3.png -> entomo_y, skipping.
# Low conf 0.68 for Bruech06A_3 (1)_5.png -> entomo_y, skipping.
# Low conf 0.70 for Bruech06A_3 (35)_8.png -> entomo_y, skipping.
# Low conf 0.60 for Bruech06A_3 (9)_3.png -> prositg, skipping.
# Low conf 0.71 for Bruech06A_3 (20)_2.png -> entomo_y, skipping.
# Low conf 0.81 for Bruech09A_3 (4)_5.png -> prositg, skipping.
# Low conf 0.69 for Bruech06A_3 (27)_10.png -> entomo_y, skipping.
# Low conf 0.81 for Bruech06A_3 (35)_6.png -> entomo_y, skipping.
# Low conf 0.67 for Bruech06A_3 (27)_8.png -> sym, skipping.
# Low conf 0.54 for Bruech06A_3 (16)_2.png -> sym, skipping.
# Low conf 0.44 for Bruech06A_3 (8)_6.png -> meso_h, skipping.
# Low conf 0.59 for Bruech11A_3 (11)_5.png -> meso_h, skipping.
# Low conf 0.61 for Bruech08A_3 (9)_4.png -> sym, skipping.
# Low conf 0.69 for Bruech06A_3 (22)_1.png -> entomo_y, skipping.
# Low conf 0.73 for Bruech06A_3 (33)_9.png -> entomo_y, skipping.
# Low conf 0.61 for Bruech06A_3 (12)_8.png -> entomo_y, skipping.
# Low conf 0.82 for Bruech06A_3 (35)_1.png -> entomo_y, skipping.
# Low conf 0.56 for Bruech06A_3 (23)_11.png -> entomo_y, skipping.
# Low conf 0.53 for Bruech09A_3 (12)_4.png -> prositg, skipping.
# Low conf 0.55 for Bruech06A_3 (7)_3.png -> entomo_y, skipping.
# Low conf 0.75 for Bruech06A_3 (30)_14.png -> entomo_y, skipping.
# Low conf 0.75 for Bruech08A_3 (1)_8.png -> meso_h, skipping.
# Low conf 0.59 for Bruech09A_3 (9)_6.png -> sym, skipping.
# Low conf 0.56 for Bruech11A_3 (14)_7.png -> entomo_y, skipping.
# Low conf 0.85 for Bruech06A_3 (29)_8.png -> entomo_y, skipping.
# Low conf 0.68 for Bruech11A_3 (10)_6.png -> entomo_y, skipping.
# Low conf 0.57 for Bruech11A_3 (19)_5.png -> entomo_y, skipping.
# Low conf 0.57 for Bruech06A_3 (5)_8.png -> sym, skipping.
# Low conf 0.82 for Bruech06A_3 (5)_7.png -> entomo_y, skipping.
# Low conf 0.65 for Bruech06A_3 (26)_5.png -> sym, skipping.
# Low conf 0.37 for Bruech06A_3 (29)_5.png -> sym, skipping.
# Low conf 0.60 for Bruech09A_3 (11)_4.png -> meso_h, skipping.
# Low conf 0.75 for Bruech06A_3 (26)_2.png -> entomo_y, skipping.
